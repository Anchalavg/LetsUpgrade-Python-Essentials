# %% [markdown]
# #list and its functions

# %%
list = [1,2,3,4,5]

# %%
list
# Out:
# [1, 2, 3, 4, 5]

# %%
list.append("anchal")

# %%
list
# Out:
# [1, 2, 3, 4, 5, 'anchal']

# %%
list.remove(3)

# %%
list.pop(0)
# Out:
# 1

# %%
list.insert(5,"seth")

# %%
list
# Out:
# [1, 2, 4, 5, 'anchal', 'seth']

# %%
list.clear()

# %%
list
# Out:
# []

# %% [markdown]
# #Dictionary and its default data type

# %%
dict = {"name":"anchal","title":"seth","dob":"7"}

# %%
dict
# Out:
# {'dob': '7', 'name': 'anchal', 'title': 'seth'}

# %%
dict["number"]="23415"

# %%
dict
# Out:
# {'dob': '7', 'name': 'anchal', 'number': '23415', 'title': 'seth'}

# %%
dict.get("dob")
# Out:
# '7'

# %%
dict.values()
# Out:
# dict_values(['anchal', 'seth', '7', '23415'])

# %%
dict.popitem()
# Out:
# ('number', '23415')

# %%
dict.setdefault("dob")
# Out:
# '7'

# %% [markdown]
# # sets and its function

# %%
set = {"silver","light",2,7,2,3,5}

# %%
set
# Out:
# {2, 3, 5, 7, 'light', 'silver'}

# %%
set.add(9)

# %%
set
# Out:
# {2, 3, 5, 7, 9, 'light', 'silver'}

# %%
set.update([1,6,4])

# %%
set
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9, 'light', 'silver'}

# %%
set2 = {4,6,0,8}

# %%
set3 = set.intersection(set2)

# %%
set3
# Out:
# {4, 6}

# %%
 set5 = set2.difference(set3)

# %%
set5
# Out:
# {0, 8}

# %%
set6 = set5.isdisjoint(set)

# %%
set6
# Out:
# True

# %% [markdown]
# #Tuple and its default method

# %%
tuple = ("anchal","18","konnagar")

# %%
tuple
# Out:
# ('anchal', '18', 'konnagar')

# %%
tuple.count(2)
# Out:
# 0

# %%
tuple.index("18")
# Out:
# 1

# %% [markdown]
# #String and its function

# %%
str = "konnagar"
str1 = "hatirkul address"

# %%
str1
# Out:
# 'hatirkul address'

# %%
str.find("a")
# Out:
# 4

# %%
str.endswith("r")
# Out:
# True

# %%
str.replace("konnagar",("hooghly"))
# Out:
# 'hooghly'

# %%
str2 = "   hello   "

# %%
str2
# Out:
# '   hello   '

# %%
str2.lstrip()
# Out:
# 'hello   '

# %%
str1.split()
# Out:
# ['hatirkul', 'address']
